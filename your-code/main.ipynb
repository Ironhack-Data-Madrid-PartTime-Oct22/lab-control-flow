# %% [markdown]
# ## Words

# %%
words = ['play', 'filling', 'bar', 'theatre', 'easygoing', 'date', 'lead', 'that', 'story',  'island']

# %% [markdown]
# **Print every word in upper case**

# %%
words2 = ",".join(words)

# %%
type(words2)
# Out:
# str

# %%
words2.upper()
# Out:
# 'PLAY,FILLING,BAR,THEATRE,EASYGOING,DATE,LEAD,THAT,STORY,ISLAND'

# %% [markdown]
# **Create a new list containing only words with 5 or more letters**

# %%
WORDS5 = words2.splitlines(5)

# %%
WORDS5
# Out:
# ['play,filling,bar,theatre,easygoing,date,lead,that,story,island']

# %% [markdown]
# **Print the first word starting with "t"**

# %%
#HE DADO 2000.000 vueltas por google y no me da la cabezaaa !

*first_words, last_word = WORDS5.split("t")
first_letters = ' '.join([f"{w[0].upper()}." for w in first_words])

res = f"{first_letters} {last_word}"

print(res)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [101], line 1
# ----> 1 *first_words, last_word = WORDS5.split("t")
#       2 first_letters = ' '.join([f"{w[0].upper()}." for w in first_words])
#       4 res = f"{first_letters} {last_word}"
#
# AttributeError: 'list' object has no attribute 'split'

# %%
x = words2.startswith('t')

print(x)
# Out:
# False

# %% [markdown]
# ## Numbers

# %% [markdown]
# **Create a list containing the square of every number from 1 to 10**

# %%
lista5 = []

for i in range(1, 11):
    lista5.append(i * i)
print(lista5)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %% [markdown]
# **Print a list containing the square of every odd number from 1 to 10**

# %%
lista2 = range(1,11)

# %%
lista2
# Out:
# range(1, 11)

# %%
result = [i for i in lista2 if i%2!=0]

# %%
print(result)
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# **Create a list with the squares of all multiples of 8 below 1000**

# %%
lista9 = []
for i in range(1, 1001):
    lista9.append(i * i*8)
print(lista9)
# Out:
# [8, 32, 72, 128, 200, 288, 392, 512, 648, 800, 968, 1152, 1352, 1568, 1800, 2048, 2312, 2592, 2888, 3200, 3528, 3872, 4232, 4608, 5000, 5408, 5832, 6272, 6728, 7200, 7688, 8192, 8712, 9248, 9800, 10368, 10952, 11552, 12168, 12800, 13448, 14112, 14792, 15488, 16200, 16928, 17672, 18432, 19208, 20000, 20808, 21632, 22472, 23328, 24200, 25088, 25992, 26912, 27848, 28800, 29768, 30752, 31752, 32768, 33800, 34848, 35912, 36992, 38088, 39200, 40328, 41472, 42632, 43808, 45000, 46208, 47432, 48672, 49928, 51200, 52488, 53792, 55112, 56448, 57800, 59168, 60552, 61952, 63368, 64800, 66248, 67712, 69192, 70688, 72200, 73728, 75272, 76832, 78408, 80000, 81608, 83232, 84872, 86528, 88200, 89888, 91592, 93312, 95048, 96800, 98568, 100352, 102152, 103968, 105800, 107648, 109512, 111392, 113288, 115200, 117128, 119072, 121032, 123008, 125000, 127008, 129032, 131072, 133128, 135200, 137288, 139392, 141512, 143648, 145800, 147968, 150152, 152352, 154568, 156800, 159048, 161312, 163592, 165888, 168200, 170528, 172872, 175232, 177608, 180000, 182408, 184832, 187272, 189728, 192200, 194688, 197192, 199712, 202248, 204800, 207368, 209952, 212552, 215168, 217800, 220448, 223112, 225792, 228488, 231200, 233928, 236672, 239432, 242208, 245000, 247808, 250632, 253472, 256328, 259200, 262088, 264992, 267912, 270848, 273800, 276768, 279752, 282752, 285768, 288800, 291848, 294912, 297992, 301088, 304200, 307328, 310472, 313632, 316808, 320000, 323208, 326432, 329672, 332928, 336200, 339488, 342792, 346112, 349448, 352800, 356168, 359552, 362952, 366368, 369800, 373248, 376712, 380192, 383688, 387200, 390728, 394272, 397832, 401408, 405000, 408608, 412232, 415872, 419528, 423200, 426888, 430592, 434312, 438048, 441800, 445568, 449352, 453152, 456968, 460800, 464648, 468512, 472392, 476288, 480200, 484128, 488072, 492032, 496008, 500000, 504008, 508032, 512072, 516128, 520200, 524288, 528392, 532512, 536648, 540800, 544968, 549152, 553352, 557568, 561800, 566048, 570312, 574592, 578888, 583200, 587528, 591872, 596232, 600608, 605000, 609408, 613832, 618272, 622728, 627200, 631688, 636192, 640712, 645248, 649800, 654368, 658952, 663552, 668168, 672800, 677448, 682112, 686792, 691488, 696200, 700928, 705672, 710432, 715208, 720000, 724808, 729632, 734472, 739328, 744200, 749088, 753992, 758912, 763848, 768800, 773768, 778752, 783752, 788768, 793800, 798848, 803912, 808992, 814088, 819200, 824328, 829472, 834632, 839808, 845000, 850208, 855432, 860672, 865928, 871200, 876488, 881792, 887112, 892448, 897800, 903168, 908552, 913952, 919368, 924800, 930248, 935712, 941192, 946688, 952200, 957728, 963272, 968832, 974408, 980000, 985608, 991232, 996872, 1002528, 1008200, 1013888, 1019592, 1025312, 1031048, 1036800, 1042568, 1048352, 1054152, 1059968, 1065800, 1071648, 1077512, 1083392, 1089288, 1095200, 1101128, 1107072, 1113032, 1119008, 1125000, 1131008, 1137032, 1143072, 1149128, 1155200, 1161288, 1167392, 1173512, 1179648, 1185800, 1191968, 1198152, 1204352, 1210568, 1216800, 1223048, 1229312, 1235592, 1241888, 1248200, 1254528, 1260872, 1267232, 1273608, 1280000, 1286408, 1292832, 1299272, 1305728, 1312200, 1318688, 1325192, 1331712, 1338248, 1344800, 1351368, 1357952, 1364552, 1371168, 1377800, 1384448, 1391112, 1397792, 1404488, 1411200, 1417928, 1424672, 1431432, 1438208, 1445000, 1451808, 1458632, 1465472, 1472328, 1479200, 1486088, 1492992, 1499912, 1506848, 1513800, 1520768, 1527752, 1534752, 1541768, 1548800, 1555848, 1562912, 1569992, 1577088, 1584200, 1591328, 1598472, 1605632, 1612808, 1620000, 1627208, 1634432, 1641672, 1648928, 1656200, 1663488, 1670792, 1678112, 1685448, 1692800, 1700168, 1707552, 1714952, 1722368, 1729800, 1737248, 1744712, 1752192, 1759688, 1767200, 1774728, 1782272, 1789832, 1797408, 1805000, 1812608, 1820232, 1827872, 1835528, 1843200, 1850888, 1858592, 1866312, 1874048, 1881800, 1889568, 1897352, 1905152, 1912968, 1920800, 1928648, 1936512, 1944392, 1952288, 1960200, 1968128, 1976072, 1984032, 1992008, 2000000, 2008008, 2016 ...

# %% [markdown]
# ## People

# %%
people = [
    {
        "name": "Juan",
        "age": 34,
        "n_kids": 2
    },
    {
        "name": "Pepe",
        "age": 27,
        "n_kids": 0
    },
    {
        "name": "Sonia",
        "age": 41,
        "n_kids": 1
    },
    {
        "name": "Lucía",
        "age": 22,
        "n_kids": 2
    },
    {
        "name": "Leo",
        "age": 55,
        "n_kids": 5
    }
]

# %% [markdown]
# **How many people are there?**

# %%
# Out:
# [{'name': 'Juan', 'age': 34, 'n_kids': 2},
#  {'name': 'Pepe', 'age': 27, 'n_kids': 0},
#  {'name': 'Sonia', 'age': 41, 'n_kids': 1},
#  {'name': 'Lucía', 'age': 22, 'n_kids': 2},
#  {'name': 'Leo', 'age': 55, 'n_kids': 5}]

# %% [markdown]
# **How many people have kids**?

# %%
# your code here

# %% [markdown]
# **How many kids do they have in total?**

# %%
# your code here

# %% [markdown]
# **In a year's time, names ending with "a" will have an extra kid. Create a list of dictionaries with people's info in a year's time**

# %%
# your code here
